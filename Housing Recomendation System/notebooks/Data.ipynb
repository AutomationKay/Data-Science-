# %%
import os
from dotenv import load_dotenv
import pandas as pd
import requests

#Settings
pd.set_option("display.max_columns", None)

# %%
load_dotenv('zillow.env')
API_KEY = '56da8635-db6d-4674-810a-b5b90ac3cb37'

# %%
def get_listings(API, listing_url):
    url = "https://app.scrapeak.com/v1/scrapers/zillow/listing"
    
    query_strng = {"api_key": API,
                   "url": listing_url
                   }
    return requests.request("GET",url, params=query_strng)

# %%
listing_url = ["https://www.zillow.com/miami-fl/?searchQueryState=%7B%22mapBounds%22%3A%7B%22north%22%3A25.881380922191553%2C%22east%22%3A-80.03321940771484%2C%22south%22%3A25.524388696288366%2C%22west%22%3A-80.65463359228515%7D%2C%22isMapVisible%22%3Atrue%2C%22filterState%22%3A%7B%22ah%22%3A%7B%22value%22%3Atrue%7D%2C%22sort%22%3A%7B%22value%22%3A%22globalrelevanceex%22%7D%7D%2C%22isListVisible%22%3Atrue%2C%22mapZoom%22%3A12%2C%22regionSelection%22%3A%5B%7B%22regionId%22%3A12700%2C%22regionType%22%3A6%7D%5D%2C%22pagination%22%3A%7B%7D%7D",
           "https://www.zillow.com/arlington-va/?searchQueryState=%7B%22pagination%22%3A%7B%7D%2C%22mapBounds%22%3A%7B%22north%22%3A39.04768381076157%2C%22east%22%3A-76.73007390771484%2C%22south%22%3A38.73932083199976%2C%22west%22%3A-77.35148809228515%7D%2C%22isMapVisible%22%3Atrue%2C%22filterState%22%3A%7B%22ah%22%3A%7B%22value%22%3Atrue%7D%2C%22sort%22%3A%7B%22value%22%3A%22globalrelevanceex%22%7D%7D%2C%22isListVisible%22%3Atrue%2C%22regionSelection%22%3A%5B%7B%22regionId%22%3A30258%2C%22regionType%22%3A6%7D%2C%7B%22regionId%22%3A41568%2C%22regionType%22%3A6%7D%5D%2C%22mapZoom%22%3A12%7D",
           "https://www.zillow.com/denver-co/?searchQueryState=%7B%22mapBounds%22%3A%7B%22north%22%3A40.19077327121551%2C%22east%22%3A-104.44142431542967%2C%22south%22%3A39.582769610184165%2C%22west%22%3A-105.6842526845703%7D%2C%22isMapVisible%22%3Atrue%2C%22filterState%22%3A%7B%22ah%22%3A%7B%22value%22%3Atrue%7D%2C%22sort%22%3A%7B%22value%22%3A%22globalrelevanceex%22%7D%7D%2C%22isListVisible%22%3Atrue%2C%22mapZoom%22%3A11%2C%22regionSelection%22%3A%5B%7B%22regionId%22%3A11093%2C%22regionType%22%3A6%7D%2C%7B%22regionId%22%3A30543%2C%22regionType%22%3A6%7D%5D%2C%22pagination%22%3A%7B%7D%7D",
           "https://www.zillow.com/atlanta-ga/?searchQueryState=%7B%22mapBounds%22%3A%7B%22north%22%3A33.92499099785205%2C%22east%22%3A-84.14820990771484%2C%22south%22%3A33.59560777695239%2C%22west%22%3A-84.76962409228516%7D%2C%22isMapVisible%22%3Atrue%2C%22filterState%22%3A%7B%22ah%22%3A%7B%22value%22%3Atrue%7D%2C%22sort%22%3A%7B%22value%22%3A%22globalrelevanceex%22%7D%7D%2C%22isListVisible%22%3Atrue%2C%22mapZoom%22%3A12%2C%22regionSelection%22%3A%5B%7B%22regionId%22%3A37211%2C%22regionType%22%3A6%7D%5D%2C%22pagination%22%3A%7B%7D%7D",
           "https://www.zillow.com/san-francisco-ca/?searchQueryState=%7B%22mapBounds%22%3A%7B%22north%22%3A37.85354042270874%2C%22east%22%3A-122.27797595385742%2C%22south%22%3A37.696960579597885%2C%22west%22%3A-122.58868304614258%7D%2C%22isMapVisible%22%3Atrue%2C%22filterState%22%3A%7B%22ah%22%3A%7B%22value%22%3Atrue%7D%2C%22sort%22%3A%7B%22value%22%3A%22globalrelevanceex%22%7D%7D%2C%22isListVisible%22%3Atrue%2C%22mapZoom%22%3A13%2C%22regionSelection%22%3A%5B%7B%22regionId%22%3A20330%2C%22regionType%22%3A6%7D%5D%2C%22pagination%22%3A%7B%7D%7D",
           "https://www.zillow.com/cleveland-oh/?searchQueryState=%7B%22mapBounds%22%3A%7B%22north%22%3A41.64582174753742%2C%22east%22%3A-81.39515290771485%2C%22south%22%3A41.349078810027834%2C%22west%22%3A-82.01656709228516%7D%2C%22isMapVisible%22%3Atrue%2C%22filterState%22%3A%7B%22ah%22%3A%7B%22value%22%3Atrue%7D%2C%22sort%22%3A%7B%22value%22%3A%22globalrelevanceex%22%7D%7D%2C%22isListVisible%22%3Atrue%2C%22mapZoom%22%3A12%2C%22regionSelection%22%3A%5B%7B%22regionId%22%3A24115%2C%22regionType%22%3A6%7D%5D%2C%22pagination%22%3A%7B%7D%7D",
           "https://www.zillow.com/austin-tx/?searchQueryState=%7B%22mapBounds%22%3A%7B%22north%22%3A30.635432669955684%2C%22east%22%3A-97.19473881542967%2C%22south%22%3A29.951247981999554%2C%22west%22%3A-98.4375671845703%7D%2C%22isMapVisible%22%3Atrue%2C%22filterState%22%3A%7B%22ah%22%3A%7B%22value%22%3Atrue%7D%2C%22sort%22%3A%7B%22value%22%3A%22globalrelevanceex%22%7D%7D%2C%22isListVisible%22%3Atrue%2C%22mapZoom%22%3A11%2C%22regionSelection%22%3A%5B%7B%22regionId%22%3A10221%2C%22regionType%22%3A6%7D%5D%2C%22pagination%22%3A%7B%7D%7D"
        
        
        
    ]

# %%
df_listings_combined = pd.DataFrame()

for url in listing_url:
    listing_response = get_listings(API_KEY, listing_url)
    #json_response = listing_response.json()
    
    
    #print(json_response)
    #
    df_listings = pd.json_normalize(listing_response.json()["data"]["cat1"]["searchResults"]["mapResults"])
    
    df_listings_combined = df_listings_combined.append(df_listings, ignore_index=True)
    

print(f"Number of rows: {len(df_listings_combined)}")
print(f"Number of columns: {len(df_listings_combined.columns)}")
print(df_listings_combined)
# Out:
# C:\Users\bartl\AppData\Local\Temp\ipykernel_34732\3905589833.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_listings_combined = df_listings_combined.append(df_listings, ignore_index=True)
# C:\Users\bartl\AppData\Local\Temp\ipykernel_34732\3905589833.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_listings_combined = df_listings_combined.append(df_listings, ignore_index=True)
# C:\Users\bartl\AppData\Local\Temp\ipykernel_34732\3905589833.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_listings_combined = df_listings_combined.append(df_listings, ignore_index=True)
# C:\Users\bartl\AppData\Local\Temp\ipykernel_34732\3905589833.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_listings_combined = df_listings_combined.append(df_listings, ignore_index=True)
# C:\Users\bartl\AppData\Local\Temp\ipykernel_34732\3905589833.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_listings_combined = df_listings_combined.append(df_listings, ignore_index=True)
# C:\Users\bartl\AppData\Local\Temp\ipykernel_34732\3905589833.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_listings_combined = df_listings_combined.append(df_listings, ignore_index=True)
# Number of rows: 3500
# Number of columns: 93
#               buildingId         lotId          price  minBeds  minBaths  \
# 0     25.58159--80.48648  1.001758e+09  From $185,000      3.0       2.0
# 1     25.68658--80.31459  1.001440e+09  From $449,000      2.0       2.0
# 2     25.772907--80.2633  1.001499e+09  From $395,000      2.0       2.0
# 3                    NaN           NaN       $485,000      NaN       NaN
# 4                    NaN           NaN       $460,000      NaN       NaN
# ...                  ...           ...            ...      ...       ...
# 3495                 NaN           NaN       $985,000      NaN       NaN
# 3496                 NaN           NaN       $200,000      NaN       NaN
# 3497                 NaN           NaN       $720,000      NaN       NaN
# 3498                 NaN           NaN       $815,000      NaN       NaN
# 3499                 NaN           NaN       $627,000      NaN       NaN
#
#       minArea                                             imgSrc hasImage  \
# 0      1170.0  https://photos.zillowstatic.com/fp/92d01c8965a...     True
# 1      1187.0  https://photos.zillowstatic.com/fp/d3c4f3378a0...     True
# 2       965.0  https://photos.zillowstatic.com/fp/4dfe50573a3...     True
# 3         NaN  https://photos.zillowstatic.com/fp/4061835dc9d...     True
# 4         NaN  https://photos.zillowstatic.com/fp/a83d83035b7...     True
# ...       ...                                                ...      ...
# 3495      NaN  https://photos.zillowstatic.com/fp/4760f8cff11...     True
# 3496      NaN  https://photos.zillowstatic.com/fp/04136eaec8a...     True
# 3497      NaN  https://photos.zillowstatic.com/fp/ec7b1680a43...     True
# 3498      NaN  https://photos.zillowstatic.com/fp/fa2c432826b...     True
# 3499      NaN  https://photos.zillowstatic.com/fp/897b13024d4...     True
#
#       isFeaturedListing  isShowcaseListing  unitCount  isHomeRec  \
# 0                 False              False        5.0      False
# 1                 False              False        2.0      False
# 2                 False              False        2.0      False
# 3                 False              False        NaN      False
# 4                 False              False        NaN      False
# ...                 ...                ...        ...        ...
# 3495              False              False        NaN      False
# 3496              False              False        NaN      False
# 3497              False              False        NaN      False
# 3498              False              False        NaN      False
# 3499              False              False        NaN      False
#
#                    buildingName isBuilding  \
# 0       Americana Village Condo       True
# 1     METROPOLIS II AT DADELAND       True
# 2            Mediterranea Condo       True
# 3                           NaN        NaN
# 4                           NaN        NaN
# ...                         ...        ...
# 3495                        NaN        NaN
# 3496                        NaN        NaN
# 3497                        NaN        NaN
# 3498                        NaN        NaN
# 3499                        NaN        NaN
#
#                                          address  badgeInfo statusType  \
# 0                  19800 SW 180th Ave, Miami, FL        NaN   FOR_SALE
# 1                     9066 SW 73rd Ct, Miami, FL        NaN   FOR_SALE
# 2                     117 NW 42nd Ave, Miami, FL        NaN   FOR_SALE
# 3            12066 SW 210th Ter, Miami, FL 33177        NaN   FOR_SALE
# 4               1752 NW 44th St, Miami, FL 33142        NaN   FOR_SALE
# ...                                          ...        ...        ...
# 3495            2978 SW 14th St, Miami, FL 33145        NaN   FOR_SALE
# 3496  15888 SW 95th Ave APT 327, Miami, FL 33157        NaN   FOR_SALE
# 3497            3382 SW 29th St, Miami, FL 33133        NaN   FOR_SALE
# 3498         19246 SW 132nd Ave, Miami, FL 33177        NaN   FOR_SALE
# 3499            1733 NW 16th St, Miami, FL 33125        NaN   FOR_SALE
#
#                       statusText listingType  isFavorite  \
# 0        Americana Village Condo                   False
# 1      METROPOLIS II AT DADELAND                   False
# 2             Mediterranea Condo                   False
# 3                 House for sale                   False
# 4                 House for sale                   False
# ...                          ...         ...         ...
# 3495              House for sale                   False
# 3496                 Coming soon                   False
# 3497              House for sale                   False
# 3498              House for sale                   False
# 3499  Multi-family home for sale                   False
#
#                                               detailUrl  has3DModel  \
# 0           /b/americana-village-condo-miami-fl-5XmpH2/       False
# 1                   /b/9066-sw-73rd-ct-miami-fl-5Xj6jM/       False
# 2                   /b/117-nw-42nd-ave-miami-fl-5XjbN7/       False
# 3     /homedetails/12066-SW-210th-Ter-Miami-FL-33177...       False
# 4     /homedetails/1752-NW-44th-St-Miami-FL-33142/43...        True
# ...                                                 ...         ...
# 3495  /homedetails/2978-SW-14th-St-Miami-FL-33145/43...       False
# 3496  /homedetails/15888-SW-95th-Ave-APT-327-Miami-F...       False
# 3497  /homedetails/3382-SW-29th-St-Miami-FL-33133/43...       False
# 3498  /homedetails/19246-SW-132nd-Ave-Miami-FL-33177...       False
# 3499  /homedetails/1733-NW-16th-St-Miami-FL-33125/43...       False
#
#       hasAdditionalAttributions canSaveBuilding  timeOnZillow  \
# 0                         False           False  1.671632e+08
# 1                         False           False  6.563633e+07
# 2                         False           False  8.076322e+07
# 3                         False             NaN  1.671632e+08
# 4                         False             NaN  2.535632e+08
# ...                         ...             ...           ...
# 3495                      False             NaN  3.623230e+09
# 3496                      False             NaN  7.720295e+08
# 3497                      False             NaN  5.005630e+09
# 3498                      False             NaN  1.070803e+10
# 3499                      False             NaN  3.364030e+09
#
#       latLong.latitude  latLong.longitude      zpid priceLabel  beds  baths  \
# 0            25.581590          -80.48648       NaN        NaN   NaN    NaN
# 1            25.686580          -80.31459       NaN        NaN   NaN    NaN
# 2            25.772907          -80.26330       NaN        NaN   NaN    NaN
# 3            25.570557          -80.38802  44363861      $485K   3.0    2.0
# 4            25.815348          -80.22531  43810739      $460K   3.0    2.0
# ...                ...                ...       ...        ...   ...    ...
# 3495         25.759245          -80.24221  43847505      $985K   4.0    2.0
# 3496         25.621437          -80.34663  44295955      $200K   2.0    1.0
# 3497         25.736755          -80.24945  43858949      $720K   3.0    2.0
# 3498         25.586945          -80.40550  80779920      $815K   5.0    4.0
# 3499         25.789896          -80.22391  43823709      $627K   6.0    3.0
#
#         area isUserClaimingOwner isUserConfirmedClaim visited  \
# 0        NaN                 NaN                  NaN     NaN
# 1        NaN                 NaN                  NaN     NaN
# 2        NaN                 NaN                  NaN     NaN
# 3     1509.0               False                False   False
# 4     1656.0               False                False   False
# ...      ...                 ...                  ...     ...
# 3495  2027.0               False                False   False
# 3496   845.0               False                False   False
# 3497  1645.0               False                False   False
# 3498  2612.0               False                False   False
# 3499  2457.0               False                False   False
#
#      shouldShowZestimateAsPrice       pgapt              sgapt hasVideo  \
# 0                           NaN         NaN                NaN      NaN
# 1                           NaN         NaN                NaN      NaN
# 2                           NaN         NaN                NaN      NaN
# 3                         False     ForSale  For Sale (Broker)    False
# 4                         False     ForSale  For Sale (Broker)    False
# ...                         ...         ...                ...      ...
# 3495                      False     ForSale  For Sale (Broker)    False
# 3496                      False  ComingSoon        Coming Soon    False
# 3497                      False     ForSale  For Sale (Broker)    False
# 3498                      False     ForSale  For Sale (Broker)    False
# 3499                      False     ForSale  For Sale (Broker)    False
#
#       availabilityDate variableData.type  variableData.text  \
# 0                  NaN               NaN                NaN
# 1                  NaN               NaN                NaN
# 2                  NaN               NaN                NaN
# 3                  NaN        OPEN_HOUSE  Open: Fri. 12-1pm
# 4                  NaN           3D_HOME            3D Tour
# ...                ...               ...                ...
# 3495               NaN   PRICE_REDUCTION    $65,000 (May 4)
# 3496               NaN               NaN                NaN
# 3497               NaN               NaN                NaN
# 3498               NaN               NaN                NaN
# 3499               NaN               NaN                NaN
#
#       hdpData.homeInfo.zpid hdpData.homeInfo.streetAddress  \
# 0                       NaN                            NaN
# 1                       NaN                            NaN
# 2                       NaN                            NaN
# 3                44363861.0             12066 SW 210th Ter
# 4                43810739.0                1752 NW 44th St
# ...                     ...                            ...
# 3495             43847505.0                2978 SW 14th St
# 3496             44295955.0      15888 SW 95th Ave APT 327
# 3497             43858949.0                3382 SW 29th St
# 3498             80779920.0             19246 SW 132nd Ave
# 3499             43823709.0                1733 NW 16th St
#
#      hdpData.homeInfo.zipcode hdpData.homeInfo.city hdpData.homeInfo.state  \
# 0                         NaN                   NaN                    NaN
# 1                         NaN                   NaN                    NaN
# 2                         NaN                   NaN                    NaN
# 3                       33177                 Miami                     FL
# 4                       33142                 Miami                     FL
# ...                       ...                   ...                    ...
# 3495                    33145                 Miami                     FL
# 3496                    33157                 Miami                     FL
# 3497                    33133                 Miami                     FL
# 3498                    33177                 Miami                     FL
# 3499                    33125                 Miami                     FL
#
#       hdpData.homeInfo.latitude  hdpData.homeInfo.longitude  \
# 0                           NaN                         NaN
# 1                           NaN                         NaN
# 2                           NaN                         NaN
# 3                     25.570557                   -80.38802
# 4                     25.815348                   -80.22531
# ...                         ...                         ...
# 3495                  25.759245                   -80.24221
# 3496                  25.621437                   -80.34663
# 3497                  25.736755                   -80.24945
# 3498                  25.586945                   -80.40550
# 3499                  25.789896                   -80.22391
#
#       hdpData.homeInfo.price  hdpData.homeInfo.bathrooms  \
# 0                        NaN                         NaN
# 1                        NaN                         NaN
# 2                        NaN                         NaN
# 3                   485000.0                         2.0
# 4                   460000.0                         2.0
# ...                      ...                         ...
# 3495                985000.0                         2.0
# 3496                200000.0                         1.0
# 3497                720000.0                         2.0
# 3498                815000.0                         4.0
# 3499                627000.0                         3.0
#
#       hdpData.homeInfo.bedrooms  hdpData.homeInfo.livingArea  \
# 0                           NaN                          NaN
# 1                           NaN                          NaN
# 2                           NaN                          NaN
# 3                           3.0                       1509.0
# 4                           3.0                       1656.0
# ...                         ...                          ...
# 3495                        4.0                       2027.0
# 3496                        2.0                        845.0
# 3497                        3.0                       1645.0
# 3498                        5.0                       2612.0
# 3499                        6.0                       2457.0
#
#      hdpData.homeInfo.homeType hdpData.homeInfo.homeStatus  \
# 0                          NaN                         NaN
# 1                          NaN                         NaN
# 2                          NaN                         NaN
# 3                SINGLE_FAMILY                    FOR_SALE
# 4                SINGLE_FAMILY                    FOR_SALE
# ...                        ...                         ...
# 3495             SINGLE_FAMILY                    FOR_SALE
# 3496                     CONDO                    FOR_SALE
# 3497             SINGLE_FAMILY                    FOR_SALE
# 3498             SINGLE_FAMILY                    FOR_SALE
# 3499              MULTI_FAMILY                    FOR_SALE
#
#       hdpData.homeInfo.daysOnZillow hdpData.homeInfo.isFeatured  \
# 0                               NaN                         NaN
# 1                               NaN                         NaN
# 2                               NaN                         NaN
# 3                              -1.0                       False
# 4                              -1.0                       False
# ...                             ...                         ...
# 3495                           -1.0                       False
# 3496                           -1.0                       False
# 3497                           -1.0                       False
# 3498                           -1.0                       False
# 3499                           -1.0                       False
#
#      hdpData.homeInfo.shouldHighlight  \
# 0                                 NaN
# 1                                 NaN
# 2                                 NaN
# 3                               False
# 4                               False
# ...                               ...
# 3495                            False
# 3496                            False
# 3497                            False
# 3498                            False
# 3499                            False
#
#      hdpData.homeInfo.listing_sub_type.is_openHouse  \
# 0                                               NaN
# 1                                               NaN
# 2                                               NaN
# 3                                              True
# 4                                               NaN
# ...                                             ...
# 3495                                            NaN
# 3496                                            NaN
# 3497                                            NaN
# 3498                                            NaN
# 3499                                            NaN
#
#      hdpData.homeInfo.listing_sub_type.is_FSBA hdpData.homeInfo.openHouse  \
# 0                                          NaN                        NaN
# 1                                          NaN                        NaN
# 2                                          NaN                        NaN
# 3                                         True                Fri. 12-1pm
# 4                                         True                        NaN
# ...                                        ...                        ...
# 3495                                      True                        NaN
# 3496                                       NaN                        NaN
# 3497                                      True                        NaN
# 3498                                      True                        NaN
# 3499                                      True                        NaN
#
#      hdpData.homeInfo.isUnmappable hdpData.homeInfo.isPreforeclosureAuction  \
# 0                              NaN                                      NaN
# 1                              NaN                                      NaN
# 2                              NaN                                      NaN
# 3                            False                                    False
# 4                            False                                    False
# ...                            ...                                      ...
# 3495                         False                                    False
# 3496                         False                                    False
# 3497                         False                                    False
# 3498                         False                                    False
# 3499                         False                                    False
#
#      hdpData.homeInfo.homeStatusForHDP  hdpData.homeInfo.priceForHDP  \
# 0                                  NaN                           NaN
# 1                                  NaN                           NaN
# 2                                  NaN                           NaN
# 3                             FOR_SALE                      485000.0
# 4                             FOR_SALE                      460000.0
# ...                                ...                           ...
# 3495                          FOR_SALE                      985000.0
# 3496                          FOR_SALE                      200000.0
# 3497                          FOR_SALE                      720000.0
# 3498                          FOR_SALE                      815000.0
# 3499                          FOR_SALE                      627000.0
#
#      hdpData.homeInfo.open_house_info.open_house_showing  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3     [{'open_house_start': 1685732400000, 'open_hou...
# 4                                                   NaN
# ...                                                 ...
# 3495                                                NaN
# 3496                                                NaN
# 3497                                                NaN
# 3498                                                NaN
# 3499                                                NaN
#
#      hdpData.homeInfo.isNonOwnerOccupied hdpData.homeInfo.isPremierBuilder  \
# 0                                    NaN                               NaN
# 1                                    NaN                               NaN
# 2                                    NaN                               NaN
# 3                                   True                             False
# 4                                   True                             False
# ...                                  ...                               ...
# 3495                                True                             False
# 3496                                True                             False
# 3497                                True                             False
# 3498                                True                             False
# 3499                                True                             False
#
#      hdpData.homeInfo.isZillowOwned hdpData.homeInfo.currency  \
# 0                               NaN                       NaN
# 1                               NaN                       NaN
# 2                               NaN                       NaN
# 3                             False                       USD
# 4                             False                       USD
# ...                             ...                       ...
# 3495                          False                       USD
# 3496                          False                       USD
# 3497                          False                       USD
# 3498                          False                       USD
# 3499                          False                       USD
#
#      hdpData.homeInfo.country  hdpData.homeInfo.taxAssessedValue  \
# 0                         NaN                                NaN
# 1                         NaN                                NaN
# 2                         NaN                                NaN
# 3                         USA                           337730.0
# 4                         USA                           334992.0
# ...                       ...                                ...
# 3495                      USA                           412207.0
# 3496                      USA                           118701.0
# 3497                      USA                           323579.0
# 3498                      USA                           457469.0
# 3499                      USA                           408030.0
#
#       hdpData.homeInfo.lotAreaValue hdpData.homeInfo.lotAreaUnit  \
# 0                               NaN                          NaN
# 1                               NaN                          NaN
# 2                               NaN                          NaN
# 3                       4500.000000                         sqft
# 4                       4928.000000                         sqft
# ...                             ...                          ...
# 3495                    6900.000000                         sqft
# 3496                       0.000000                         sqft
# 3497                    5500.000000                         sqft
# 3498                       0.291621                        acres
# 3499                       0.000000                         sqft
#
#      hdpData.homeInfo.isShowcaseListing  variableData  \
# 0                                   NaN           NaN
# 1                                   NaN           NaN
# 2                                   NaN           NaN
# 3                                 False           NaN
# 4                                 False           NaN
# ...                                 ...           ...
# 3495                              False           NaN
# 3496                              False           NaN
# 3497                              False           NaN
# 3498                              False           NaN
# 3499                              False           NaN
#
#       hdpData.homeInfo.zestimate  hdpData.homeInfo.rentZestimate  \
# 0                            NaN                             NaN
# 1                            NaN                             NaN
# 2                            NaN                             NaN
# 3                            NaN                             NaN
# 4                            NaN                             NaN
# ...                          ...                             ...
# 3495                    946303.0                          4664.0
# 3496                    219700.0                          1999.0
# 3497                         NaN                             NaN
# 3498                    790303.0                          5259.0
# 3499                         NaN                             NaN
#
#       hdpData.homeInfo.datePriceChanged hdpData.homeInfo.priceReduction  \
# 0                                   NaN                             NaN
# 1                                   NaN                             NaN
# 2                                   NaN                             NaN
# 3                                   NaN                             NaN
# 4                                   NaN                             NaN
# ...                                 ...                             ...
# 3495                       1.683184e+12                 $65,000 (May 4)
# 3496                                NaN                             NaN
# 3497                                NaN                             NaN
# 3498                       1.683788e+12                             NaN
# 3499                                NaN                             NaN
#
#       hdpData.homeInfo.priceChange variableData.data.isFresh  \
# 0                              NaN                       NaN
# 1                              NaN                       NaN
# 2                              NaN                       NaN
# 3                              NaN                       NaN
# 4                              NaN                       NaN
# ...                            ...                       ...
# 3495                      -65000.0                       NaN
# 3496                           NaN                       NaN
# 3497                           NaN                       NaN
# 3498                       20000.0                       NaN
# 3499                           NaN                       NaN
#
#      hdpData.homeInfo.unit hdpData.homeInfo.listing_sub_type.is_bankOwned  \
# 0                      NaN                                            NaN
# 1                      NaN                                            NaN
# 2                      NaN                                            NaN
# 3                      NaN                                            NaN
# 4                      NaN                                            NaN
# ...                    ...                                            ...
# 3495                   NaN                                            NaN
# 3496               Apt 327                                            NaN
# 3497                   NaN                                            NaN
# 3498                   NaN                                            NaN
# 3499                   NaN                                            NaN
#
#      lotAreaString hdpData.homeInfo.listing_sub_type.is_newHome  \
# 0              NaN                                          NaN
# 1              NaN                                          NaN
# 2              NaN                                          NaN
# 3              NaN                                          NaN
# 4              NaN                                          NaN
# ...            ...                                          ...
# 3495           NaN                                          NaN
# 3496           NaN                                          NaN
# 3497           NaN                                          NaN
# 3498           NaN                                          NaN
# 3499           NaN                                          NaN
#
#      hdpData.homeInfo.newConstructionType  hdpData.homeInfo.videoCount  \
# 0                                     NaN                          NaN
# 1                                     NaN                          NaN
# 2                                     NaN                          NaN
# 3                                     NaN                          NaN
# 4                                     NaN                          NaN
# ...                                   ...                          ...
# 3495                                  NaN                          NaN
# 3496                                  NaN                          NaN
# 3497                                  NaN                          NaN
# 3498                                  NaN                          NaN
# 3499                                  NaN                          NaN
#
#      streetViewMetadataURL streetViewURL  \
# 0                      NaN           NaN
# 1                      NaN           NaN
# 2                      NaN           NaN
# 3                      NaN           NaN
# 4                      NaN           NaN
# ...                    ...           ...
# 3495                   NaN           NaN
# 3496                   NaN           NaN
# 3497                   NaN           NaN
# 3498                   NaN           NaN
# 3499                   NaN           NaN
#
#      hdpData.homeInfo.isRentalWithBasePrice  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
# ...                                     ...
# 3495                                    NaN
# 3496                                    NaN
# 3497                                    NaN
# 3498                                    NaN
# 3499                                    NaN
#
#      hdpData.homeInfo.listing_sub_type.is_forAuction  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# ...                                              ...
# 3495                                             NaN
# 3496                                             NaN
# 3497                                             NaN
# 3498                                             NaN
# 3499                                             NaN
#
#      hdpData.homeInfo.listing_sub_type.is_comingSoon
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# ...                                              ...
# 3495                                             NaN
# 3496                                            True
# 3497                                             NaN
# 3498                                             NaN
# 3499                                             NaN
#
# [3500 rows x 93 columns]
# C:\Users\bartl\AppData\Local\Temp\ipykernel_34732\3905589833.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_listings_combined = df_listings_combined.append(df_listings, ignore_index=True)

# %%
URL = "https://www.zillow.com/homes/for_sale/?searchQueryState=%7B%22mapBounds%22%3A%7B%22west%22%3A-81.8451148317744%2C%22east%22%3A-79.35945809349315%2C%22south%22%3A25.112984124942425%2C%22north%22%3A26.53941967969499%7D%2C%22isMapVisible%22%3Atrue%2C%22filterState%22%3A%7B%22sort%22%3A%7B%22value%22%3A%22globalrelevanceex%22%7D%2C%22ah%22%3A%7B%22value%22%3Atrue%7D%7D%2C%22isListVisible%22%3Atrue%2C%22customRegionId%22%3A%229579c64790X1-CR1mje822oy4urp_1fut9l%22%7D"

listing_response = get_listings(API_KEY, URL)

# %%
listing_response.json().keys()
# Out:
# dict_keys(['is_success', 'data', 'message'])

# %%
listing_response.json()["is_success"]
# Out:
# True
