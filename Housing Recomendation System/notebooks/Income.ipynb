# %%
#Packages used for model
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

#For visuals
warnings.filterwarnings('ignore')
# %matplotlib inline
pd.set_option('display.max_columns',None)

# %%
adult = pd.read_csv('C:/Users/bartl/Desktop/Data-Science-/Housing Recomendation System/data/adult.csv')

adult.head()
# Out:
#    age workclass  fnlwgt     education  education.num marital.status  \
# 0   90         ?   77053       HS-grad              9        Widowed
# 1   82   Private  132870       HS-grad              9        Widowed
# 2   66         ?  186061  Some-college             10        Widowed
# 3   54   Private  140359       7th-8th              4       Divorced
# 4   41   Private  264663  Some-college             10      Separated
#
#           occupation   relationship   race     sex  capital.gain  \
# 0                  ?  Not-in-family  White  Female             0
# 1    Exec-managerial  Not-in-family  White  Female             0
# 2                  ?      Unmarried  Black  Female             0
# 3  Machine-op-inspct      Unmarried  White  Female             0
# 4     Prof-specialty      Own-child  White  Female             0
#
#    capital.loss  hours.per.week native.country income
# 0          4356              40  United-States  <=50K
# ...

# %%
adult = adult.replace({'?': 'Unknown'})

# %%
#Creating a new column to hold random income
adult['random_income'] = adult['income']
 
#Create a mask identity for rows that are '>50k'
mask = adult['income'] == '>50K'

#Create a mask identity for raws that are '<=50k'
mask1 = adult['income'] == '<=50k'

#Generate random income value in rows that are over '50k' in income
adult.loc[mask, 'random_income'] = np.random.uniform(50001, 400000, size=np.sum(mask))

#Generate random income value in rows that are under '50k' in income
adult.loc[mask1, 'random_income'] = np.random.uniform(1000, 50000, size=np.sum(mask1))

#adult['income'].fillna(0, inplace=True)

#Convert the income column to integer type
adult['random_income'] = adult['random_income'].astype(int)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\bartl\Desktop\Data-Science-\Housing Recomendation System\notebooks\Income.ipynb Cell 4 in <cell line: 19>()
#      <a href='vscode-notebook-cell:/c%3A/Users/bartl/Desktop/Data-Science-/Housing%20Recomendation%20System/notebooks/Income.ipynb#W3sZmlsZQ%3D%3D?line=13'>14</a> adult.loc[mask1, 'random_income'] = np.random.uniform(1000, 50000, size=np.sum(mask1))
#      <a href='vscode-notebook-cell:/c%3A/Users/bartl/Desktop/Data-Science-/Housing%20Recomendation%20System/notebooks/Income.ipynb#W3sZmlsZQ%3D%3D?line=15'>16</a> #adult['income'].fillna(0, inplace=True)
#      <a href='vscode-notebook-cell:/c%3A/Users/bartl/Desktop/Data-Science-/Housing%20Recomendation%20System/notebooks/Income.ipynb#W3sZmlsZQ%3D%3D?line=16'>17</a>
# ...
