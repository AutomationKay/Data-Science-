# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline
pd.set_option('display.max_columns',None)

# %%
adult = pd.read_csv('../Adult Income/data/adult.csv')
adult.head()
# Out:
#    age workclass  fnlwgt     education  education.num marital.status  \
# 0   90         ?   77053       HS-grad              9        Widowed
# 1   82   Private  132870       HS-grad              9        Widowed
# 2   66         ?  186061  Some-college             10        Widowed
# 3   54   Private  140359       7th-8th              4       Divorced
# 4   41   Private  264663  Some-college             10      Separated
#
#           occupation   relationship   race     sex  capital.gain  \
# 0                  ?  Not-in-family  White  Female             0
# 1    Exec-managerial  Not-in-family  White  Female             0
# 2                  ?      Unmarried  Black  Female             0
# 3  Machine-op-inspct      Unmarried  White  Female             0
# 4     Prof-specialty      Own-child  White  Female             0
#
#    capital.loss  hours.per.week native.country income
# 0          4356              40  United-States  <=50K
# ...

# %%
adult = adult.replace({'?': 'Unknown'})

# %%
adult.describe().T
# Out:
#                   count           mean            std      min       25%  \
# age             32561.0      38.581647      13.640433     17.0      28.0
# fnlwgt          32561.0  189778.366512  105549.977697  12285.0  117827.0
# education.num   32561.0      10.080679       2.572720      1.0       9.0
# capital.gain    32561.0    1077.648844    7385.292085      0.0       0.0
# capital.loss    32561.0      87.303830     402.960219      0.0       0.0
# hours.per.week  32561.0      40.437456      12.347429      1.0      40.0
#
#                      50%       75%        max
# age                 37.0      48.0       90.0
# fnlwgt          178356.0  237051.0  1484705.0
# education.num       10.0      12.0       16.0
# capital.gain         0.0       0.0    99999.0
# capital.loss         0.0       0.0     4356.0
# hours.per.week      40.0      45.0       99.0

# %%
adult['hours.per.week'].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
plt.hist(adult['income'])
plt.title('Adult Income Split')
plt.xlabel('Adult Income')
plt.ylabel('Number of Adults')
plt.show()

# %%
adult_f = adult[adult['sex'] == 'Female']
adult_f.head()
# Out:
#    age workclass  fnlwgt     education  education.num marital.status  \
# 0   90   Unknown   77053       HS-grad              9        Widowed
# 1   82   Private  132870       HS-grad              9        Widowed
# 2   66   Unknown  186061  Some-college             10        Widowed
# 3   54   Private  140359       7th-8th              4       Divorced
# 4   41   Private  264663  Some-college             10      Separated
#
#           occupation   relationship   race     sex  capital.gain  \
# 0            Unknown  Not-in-family  White  Female             0
# 1    Exec-managerial  Not-in-family  White  Female             0
# 2            Unknown      Unmarried  Black  Female             0
# 3  Machine-op-inspct      Unmarried  White  Female             0
# 4     Prof-specialty      Own-child  White  Female             0
#
#    capital.loss  hours.per.week native.country income
# 0          4356              40  United-States  <=50K
# ...

# %%
adult_m = adult[adult['sex'] == 'Male']
adult_m.head()
# Out:
#     age         workclass  fnlwgt     education  education.num marital.status  \
# 6    38           Private  150601          10th              6      Separated
# 9    41           Private   70037  Some-college             10  Never-married
# 11   38  Self-emp-not-inc  164526   Prof-school             15  Never-married
# 13   32           Private  136204       Masters             14      Separated
# 14   51           Unknown  172175     Doctorate             16  Never-married
#
#          occupation   relationship   race   sex  capital.gain  capital.loss  \
# 6      Adm-clerical      Unmarried  White  Male             0          3770
# 9      Craft-repair      Unmarried  White  Male             0          3004
# 11   Prof-specialty  Not-in-family  White  Male             0          2824
# 13  Exec-managerial  Not-in-family  White  Male             0          2824
# 14          Unknown  Not-in-family  White  Male             0          2824
#
# ...

# %%
adult_m['workclass'].value_counts()
# Out:
# Private             14944
# Self-emp-not-inc     2142
# Local-gov            1258
# Unknown               997
# Self-emp-inc          981
# State-gov             809
# Federal-gov           645
# Without-pay             9
# Never-worked            5
# Name: workclass, dtype: int64

# %%
adult_f['workclass'].value_counts()
# Out:
# Private             7752
# Unknown              839
# Local-gov            835
# State-gov            489
# Self-emp-not-inc     399
# Federal-gov          315
# Self-emp-inc         135
# Without-pay            5
# Never-worked           2
# Name: workclass, dtype: int64

# %%
plt.scatter(x=adult['age'], y=adult['marital.status'])
plt.title('Age to Marital Status Comparison')
plt.xlabel('Adult Age')
plt.ylabel('Marital Status')
plt.show()

# %%
adult['workclass'].value_counts()
# Out:
# Private             22696
# Self-emp-not-inc     2541
# Local-gov            2093
# Unknown              1836
# State-gov            1298
# Self-emp-inc         1116
# Federal-gov           960
# Without-pay            14
# Never-worked            7
# Name: workclass, dtype: int64
